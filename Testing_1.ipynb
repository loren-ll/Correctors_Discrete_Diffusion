# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from scipy.special import logsumexp
import pickle
import json
import os
import time
from plotting_functions import plot_method_comparison, plot_gillespie_nmc_comparison
from saving_experiments import save_samples, load_samples, save_samples_summary
from main_code import run_diffusion_experiment, add_gillespie_reverse, add_tau_leap_reverse

# %%
import time
import numpy as np

# ===== Define Parameters =====
N = 10      # Number of dimensions
L = 3      # Vocabulary size per dimension
r = 10     # Number of mixture components

# Create mixture model
w = np.ones(r) / r
mu = np.random.dirichlet([1]*L, size=(r, N))  # Shape: (r, N, L)

# Diffusion parameters
beta = 5.0  # Masking rate
T = 3.5    # Terminal time

# Checkpoint times (physical time from 0 to T)
u = np.linspace(0, 1, 31)
checkpoint_times = T * (u ** 12)  # More checkpoints near t=0

# List of n_mc values to try
n_mc_list = [300_000, 600_000, 1_200_000, 2_000_000]

print("=" * 70)
print("GILLESPIE N_MC COMPARISON EXPERIMENT (LIGHTWEIGHT PMF SAVE)")
print("=" * 70)
print(f"\nParameters:")
print(f"  N (dimensions) = {N}")
print(f"  L (vocab size) = {L}")
print(f"  r (components) = {r}")
print(f"  beta (rate)    = {beta}")
print(f"  T (term time)  = {T}")
print(f"  n_mc values    = {n_mc_list}")
print(f"  checkpoints    = {len(checkpoint_times)}")

# ===== Run Experiments for Each n_mc =====
samples_dict = {}
filenames = {}
timing_results = {}

for n_mc in n_mc_list:
    print("\n" + "=" * 70)
    print(f"Running experiment with n_mc = {n_mc}")
    print("=" * 70)
    
    # Start total timer
    total_start = time.time()
    
    # Run forward diffusion
    forward_start = time.time()
    samples = run_diffusion_experiment(w, mu, beta, T, n_mc, checkpoint_times)
    forward_time = time.time() - forward_start
    
    # Add Gillespie reverse
    gillespie_start = time.time()
    add_gillespie_reverse(samples, w, mu, beta, T)
    gillespie_time = time.time() - gillespie_start
    
    # Total time
    total_time = time.time() - total_start
    
    # Store timing
    timing_results[n_mc] = {
        'forward': forward_time,
        'gillespie': gillespie_time,
        'total': total_time
    }
    
    # Print timing
    print(f"\n⏱️  Timing for n_mc={n_mc}:")
    print(f"  Forward sampling:   {forward_time:.2f} seconds ({forward_time/60:.2f} minutes)")
    print(f"  Gillespie reverse:  {gillespie_time:.2f} seconds ({gillespie_time/60:.2f} minutes)")
    print(f"  Total:              {total_time:.2f} seconds ({total_time/60:.2f} minutes)")
    print(f"  Time per sample:    {(total_time/n_mc)*1000:.3f} ms")
    
    # Store in dict (keep full samples for verification)
    samples_dict[n_mc] = samples
    
    # Prepare metadata
    experiment_metadata = {
        'N': N,
        'L': L,
        'r': r,
        'beta': beta,
        'T': T,
        'n_mc': n_mc,
        'w': w.tolist(),
        'mu': mu.tolist(),  # ← Save full mu, not just shape
        'checkpoint_formula': 'T * (u ** 12) where u = linspace(0, 1, 31)',
        'n_checkpoints': len(checkpoint_times),
        'methods': samples.list_methods(),
        'timing': timing_results[n_mc],
        'date': '2026-05-23',
        'notes': f'Gillespie baseline with n_mc={n_mc} (LIGHTWEIGHT PMF SAVE)'
    }
    
    # Save samples
    filename = f'gillespie_nmc_{n_mc}'
    filenames[n_mc] = filename
    
    print(f"\n💾 Saving samples for n_mc={n_mc}...")
    # ← KEY CHANGE: Add lightweight=True and L parameter
    save_samples(samples, filename + '.pkl', metadata=experiment_metadata, 
                 lightweight=True, L=L)
    save_samples_summary(samples, filename + '_summary.json', metadata=experiment_metadata)

# ===== Reload and Verify =====
print("\n" + "=" * 70)
print("VERIFICATION: Reloading saved samples and checking integrity")
print("=" * 70)

for n_mc in n_mc_list:
    print(f"\nVerifying n_mc={n_mc}...")
    
    # Load samples (will be PMF dict, not DiffusionSamples object)
    filename = filenames[n_mc]
    loaded_data, loaded_metadata = load_samples(filename + '.pkl')
    
    # Original samples
    original_samples = samples_dict[n_mc]
    
    # Verify it's lightweight format
    assert loaded_data.get('lightweight', False) == True, \
        f"Expected lightweight format for {n_mc}"
    
    # Verify metadata
    assert loaded_data['metadata']['n_mc'] == original_samples.metadata['n_mc'], \
        f"n_mc mismatch for {n_mc}"
    assert loaded_data['metadata']['N'] == original_samples.metadata['N'], \
        f"N mismatch for {n_mc}"
    assert loaded_data['L'] == L, \
        f"L mismatch for {n_mc}"
    
    # Verify times
    assert np.allclose(loaded_data['times'], original_samples.times), \
        f"Times mismatch for {n_mc}"
    
    # Verify joint PMFs sum to 1
    for t in loaded_data['times']:
        forward_pmf = loaded_data['forward_pmfs'][float(t)]
        
        # Check that probabilities sum to 1
        prob_sum = np.sum(forward_pmf['probs'])
        assert np.abs(prob_sum - 1.0) < 1e-6, \
            f"Forward PMF probabilities don't sum to 1 at t={t} for n_mc={n_mc}: sum={prob_sum}"
        
        # Check that all probabilities are non-negative
        assert np.all(forward_pmf['probs'] >= 0), \
            f"Forward PMF has negative probabilities at t={t} for n_mc={n_mc}"
        
        # Check that states and probs have same length
        assert len(forward_pmf['states']) == len(forward_pmf['probs']), \
            f"States and probs length mismatch at t={t} for n_mc={n_mc}"
    
    # Verify reverse PMFs
    for method in loaded_data['reverse_pmfs'].keys():
        for t in loaded_data['times']:
            reverse_pmf = loaded_data['reverse_pmfs'][method][float(t)]
            
            # Check that probabilities sum to 1
            prob_sum = np.sum(reverse_pmf['probs'])
            assert np.abs(prob_sum - 1.0) < 1e-6, \
                f"Reverse PMF probabilities don't sum to 1 for method={method}, t={t}, n_mc={n_mc}: sum={prob_sum}"
            
            # Check that all probabilities are non-negative
            assert np.all(reverse_pmf['probs'] >= 0), \
                f"Reverse PMF has negative probabilities for method={method}, t={t}, n_mc={n_mc}"
            
            # Check that states and probs have same length
            assert len(reverse_pmf['states']) == len(reverse_pmf['probs']), \
                f"States and probs length mismatch for method={method}, t={t}, n_mc={n_mc}"
    
    print(f"  ✓ All checks passed for n_mc={n_mc}")
    print(f"  ✓ Joint PMFs verified (probabilities sum to 1)")

print("\n" + "=" * 70)
print("✓ ALL VERIFICATION CHECKS PASSED!")
print("=" * 70)

# ===== Plot Results =====
print("\n" + "=" * 70)
print("PLOTTING RESULTS")
print("=" * 70)

# Reload as PMF dicts for plotting
samples_dict_pmf = {}
for n_mc in n_mc_list:
    filename = filenames[n_mc]
    data, _ = load_samples(filename + '.pkl')
    samples_dict_pmf[n_mc] = data

# Plot comparison (plotting function handles PMF format)
fig, ax, results = plot_gillespie_nmc_comparison(
    samples_dict_pmf,
    time_start=0.0,
    time_end=T,
    filename='gillespie_nmc_comparison.png',
    show_annotations=True
)

# Print final Hellinger distances
print("\n" + "=" * 70)
print("FINAL HELLINGER DISTANCES")
print("=" * 70)
for n_mc, hellinger in sorted(results.items()):
    print(f"  n_mc={n_mc:7d}: H={hellinger:.6f}")

# Print timing summary
print("\n" + "=" * 70)
print("TIMING SUMMARY")
print("=" * 70)
print(f"{'n_mc':<12} {'Forward':<12} {'Gillespie':<12} {'Total':<12} {'Per Sample'}")
print(f"{'':12} {'(min)':<12} {'(min)':<12} {'(min)':<12} {'(ms)'}")
print("-" * 70)
for n_mc in sorted(timing_results.keys()):
    t = timing_results[n_mc]
    print(f"{n_mc:<12,} {t['forward']/60:>10.2f}  {t['gillespie']/60:>10.2f}  "
          f"{t['total']/60:>10.2f}  {(t['total']/n_mc)*1000:>10.3f}")

# Print file sizes
print("\n" + "=" * 70)
print("FILE SIZES (LIGHTWEIGHT PMF SAVES)")
print("=" * 70)
for n_mc in n_mc_list:
    filename = filenames[n_mc]
    filepath = f"{filename}/{filename}.pkl"
    if os.path.exists(filepath):
        size_mb = os.path.getsize(filepath) / (1024 * 1024)
        print(f"  n_mc={n_mc:7d}: {size_mb:.2f} MB")

# Plot zoomed version near t=0
print("\nCreating zoomed plot near t=0...")
fig_zoom, ax_zoom, _ = plot_gillespie_nmc_comparison(
    samples_dict_pmf,
    time_start=0.0,
    time_end=0.5,
    filename='gillespie_nmc_comparison_zoom.png',
    show_annotations=False
)

print("\n" + "=" * 70)
print("EXPERIMENT COMPLETE!")
print("=" * 70)
print(f"\nGenerated files:")
for n_mc in n_mc_list:
    print(f"  - {filenames[n_mc]}/")
    print(f"    ├── {filenames[n_mc]}.pkl (LIGHTWEIGHT PMF)")
    print(f"    └── {filenames[n_mc]}_summary.json")
print(f"  - gillespie_nmc_comparison.png")
print(f"  - gillespie_nmc_comparison_zoom.png")
# Out:
# ======================================================================
# GILLESPIE N_MC COMPARISON EXPERIMENT (LIGHTWEIGHT PMF SAVE)
# ======================================================================
#
# Parameters:
#   N (dimensions) = 10
#   L (vocab size) = 3
#   r (components) = 10
#   beta (rate)    = 5.0
#   T (term time)  = 3.5
#   n_mc values    = [300000, 600000, 1200000, 2000000]
#   checkpoints    = 31
#
# ======================================================================
# Running experiment with n_mc = 300000
# ======================================================================
# Running forward process...
# Running Gillespie reverse process...
#   Gillespie particle 0/300000
#   Gillespie particle 10000/300000
#   Gillespie particle 20000/300000
#   Gillespie particle 30000/300000
#   Gillespie particle 40000/300000
#   Gillespie particle 50000/300000
#   Gillespie particle 60000/300000
#   Gillespie particle 70000/300000
#   Gillespie particle 80000/300000
#   Gillespie particle 90000/300000
#   Gillespie particle 100000/300000
#   Gillespie particle 110000/300000
#   Gillespie particle 120000/300000
#   Gillespie particle 130000/300000
#   Gillespie particle 140000/300000
#   Gillespie particle 150000/300000
#   Gillespie particle 160000/300000
#   Gillespie particle 170000/300000
#   Gillespie particle 180000/300000
#   Gillespie particle 190000/300000
#   Gillespie particle 200000/300000
#   Gillespie particle 210000/300000
#   Gillespie particle 220000/300000
#   Gillespie particle 230000/300000
#   Gillespie particle 240000/300000
#   Gillespie particle 250000/300000
#   Gillespie particle 260000/300000
#   Gillespie particle 270000/300000
#   Gillespie particle 280000/300000
#   Gillespie particle 290000/300000
#
# ⏱️  Timing for n_mc=300000:
#   Forward sampling:   105.15 seconds (1.75 minutes)
#   Gillespie reverse:  148.48 seconds (2.47 minutes)
#   Total:              253.63 seconds (4.23 minutes)
#   Time per sample:    0.845 ms
#
# 💾 Saving samples for n_mc=300000...
# Computing empirical joint PMFs for lightweight save...
# Samples saved (LIGHTWEIGHT - Joint PMFs) to: gillespie_nmc_300000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - File size: 101.31 MB
#   - n_mc: 300000, N: 10
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Summary saved to: gillespie_nmc_300000_summary/gillespie_nmc_300000_summary_summary.json
#
# ======================================================================
# Running experiment with n_mc = 600000
# ======================================================================
# Running forward process...
# Running Gillespie reverse process...
#   Gillespie particle 0/600000
#   Gillespie particle 10000/600000
#   Gillespie particle 20000/600000
#   Gillespie particle 30000/600000
#   Gillespie particle 40000/600000
#   Gillespie particle 50000/600000
#   Gillespie particle 60000/600000
#   Gillespie particle 70000/600000
#   Gillespie particle 80000/600000
#   Gillespie particle 90000/600000
#   Gillespie particle 100000/600000
#   Gillespie particle 110000/600000
#   Gillespie particle 120000/600000
#   Gillespie particle 130000/600000
#   Gillespie particle 140000/600000
#   Gillespie particle 150000/600000
#   Gillespie particle 160000/600000
#   Gillespie particle 170000/600000
#   Gillespie particle 180000/600000
#   Gillespie particle 190000/600000
#   Gillespie particle 200000/600000
#   Gillespie particle 210000/600000
#   Gillespie particle 220000/600000
#   Gillespie particle 230000/600000
#   Gillespie particle 240000/600000
#   Gillespie particle 250000/600000
#   Gillespie particle 260000/600000
#   Gillespie particle 270000/600000
#   Gillespie particle 280000/600000
#   Gillespie particle 290000/600000
#   Gillespie particle 300000/600000
#   Gillespie particle 310000/600000
#   Gillespie particle 320000/600000
#   Gillespie particle 330000/600000
#   Gillespie particle 340000/600000
#   Gillespie particle 350000/600000
#   Gillespie particle 360000/600000
#   Gillespie particle 370000/600000
#   Gillespie particle 380000/600000
#   Gillespie particle 390000/600000
#   Gillespie particle 400000/600000
#   Gillespie particle 410000/600000
#   Gillespie particle 420000/600000
#   Gillespie particle 430000/600000
#   Gillespie particle 440000/600000
#   Gillespie particle 450000/600000
#   Gillespie particle 460000/600000
#   Gillespie particle 470000/600000
#   Gillespie particle 480000/600000
#   Gillespie particle 490000/600000
#   Gillespie particle 500000/600000
#   Gillespie particle 510000/600000
#   Gillespie particle 520000/600000
#   Gillespie particle 530000/600000
#   Gillespie particle 540000/600000
#   Gillespie particle 550000/600000
#   Gillespie particle 560000/600000
#   Gillespie particle 570000/600000
#   Gillespie particle 580000/600000
#   Gillespie particle 590000/600000
#
# ⏱️  Timing for n_mc=600000:
#   Forward sampling:   208.55 seconds (3.48 minutes)
#   Gillespie reverse:  299.47 seconds (4.99 minutes)
#   Total:              508.01 seconds (8.47 minutes)
#   Time per sample:    0.847 ms
#
# 💾 Saving samples for n_mc=600000...
# Computing empirical joint PMFs for lightweight save...
# Samples saved (LIGHTWEIGHT - Joint PMFs) to: gillespie_nmc_600000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - File size: 141.53 MB
#   - n_mc: 600000, N: 10
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Summary saved to: gillespie_nmc_600000_summary/gillespie_nmc_600000_summary_summary.json
#
# ======================================================================
# Running experiment with n_mc = 1200000
# ======================================================================
# Running forward process...
# Running Gillespie reverse process...
#   Gillespie particle 0/1200000
#   Gillespie particle 10000/1200000
#   Gillespie particle 20000/1200000
#   Gillespie particle 30000/1200000
#   Gillespie particle 40000/1200000
#   Gillespie particle 50000/1200000
#   Gillespie particle 60000/1200000
#   Gillespie particle 70000/1200000
#   Gillespie particle 80000/1200000
#   Gillespie particle 90000/1200000
#   Gillespie particle 100000/1200000
#   Gillespie particle 110000/1200000
#   Gillespie particle 120000/1200000
#   Gillespie particle 130000/1200000
#   Gillespie particle 140000/1200000
#   Gillespie particle 150000/1200000
#   Gillespie particle 160000/1200000
#   Gillespie particle 170000/1200000
#   Gillespie particle 180000/1200000
#   Gillespie particle 190000/1200000
#   Gillespie particle 200000/1200000
#   Gillespie particle 210000/1200000
#   Gillespie particle 220000/1200000
#   Gillespie particle 230000/1200000
#   Gillespie particle 240000/1200000
#   Gillespie particle 250000/1200000
#   Gillespie particle 260000/1200000
#   Gillespie particle 270000/1200000
#   Gillespie particle 280000/1200000
#   Gillespie particle 290000/1200000
#   Gillespie particle 300000/1200000
#   Gillespie particle 310000/1200000
#   Gillespie particle 320000/1200000
#   Gillespie particle 330000/1200000
#   Gillespie particle 340000/1200000
#   Gillespie particle 350000/1200000
#   Gillespie particle 360000/1200000
#   Gillespie particle 370000/1200000
#   Gillespie particle 380000/1200000
#   Gillespie particle 390000/1200000
#   Gillespie particle 400000/1200000
#   Gillespie particle 410000/1200000
#   Gillespie particle 420000/1200000
#   Gillespie particle 430000/1200000
#   Gillespie particle 440000/1200000
#   Gillespie particle 450000/1200000
#   Gillespie particle 460000/1200000
#   Gillespie particle 470000/1200000
#   Gillespie particle 480000/1200000
#   Gillespie particle 490000/1200000
#   Gillespie particle 500000/1200000
#   Gillespie particle 510000/1200000
#   Gillespie particle 520000/1200000
#   Gillespie particle 530000/1200000
#   Gillespie particle 540000/1200000
#   Gillespie particle 550000/1200000
#   Gillespie particle 560000/1200000
#   Gillespie particle 570000/1200000
#   Gillespie particle 580000/1200000
#   Gillespie particle 590000/1200000
#   Gillespie particle 600000/1200000
#   Gillespie particle 610000/1200000
#   Gillespie particle 620000/1200000
#   Gillespie particle 630000/1200000
#   Gillespie particle 640000/1200000
#   Gillespie particle 650000/1200000
#   Gillespie particle 660000/1200000
#   Gillespie particle 670000/1200000
#   Gillespie particle 680000/1200000
#   Gillespie particle 690000/1200000
#   Gillespie particle 700000/1200000
#   Gillespie particle 710000/1200000
#   Gillespie particle 720000/1200000
#   Gillespie particle 730000/1200000
#   Gillespie particle 740000/1200000
#   Gillespie particle 750000/1200000
#   Gillespie particle 760000/1200000
#   Gillespie particle 770000/1200000
#   Gillespie particle 780000/1200000
#   Gillespie particle 790000/1200000
#   Gillespie particle 800000/1200000
#   Gillespie particle 810000/1200000
#   Gillespie particle 820000/1200000
#   Gillespie particle 830000/1200000
#   Gillespie particle 840000/1200000
#   Gillespie particle 850000/1200000
#   Gillespie particle 860000/1200000
#   Gillespie particle 870000/1200000
#   Gillespie particle 880000/1200000
#   Gillespie particle 890000/1200000
#   Gillespie particle 900000/1200000
#   Gillespie particle 910000/1200000
#   Gillespie particle 920000/1200000
#   Gillespie particle 930000/1200000
#   Gillespie particle 940000/1200000
#   Gillespie particle 950000/1200000
#   Gillespie particle 960000/1200000
#   Gillespie particle 970000/1200000
#   Gillespie particle 980000/1200000
#   Gillespie particle 990000/1200000
#   Gillespie particle 1000000/1200000
#   Gillespie particle 1010000/1200000
#   Gillespie particle 1020000/1200000
#   Gillespie particle 1030000/1200000
#   Gillespie particle 1040000/1200000
#   Gillespie particle 1050000/1200000
#   Gillespie particle 1060000/1200000
#   Gillespie particle 1070000/1200000
#   Gillespie particle 1080000/1200000
#   Gillespie particle 1090000/1200000
#   Gillespie particle 1100000/1200000
#   Gillespie particle 1110000/1200000
#   Gillespie particle 1120000/1200000
#   Gillespie particle 1130000/1200000
#   Gillespie particle 1140000/1200000
#   Gillespie particle 1150000/1200000
#   Gillespie particle 1160000/1200000
#   Gillespie particle 1170000/1200000
#   Gillespie particle 1180000/1200000
#   Gillespie particle 1190000/1200000
#
# ⏱️  Timing for n_mc=1200000:
#   Forward sampling:   422.61 seconds (7.04 minutes)
#   Gillespie reverse:  597.84 seconds (9.96 minutes)
#   Total:              1020.45 seconds (17.01 minutes)
#   Time per sample:    0.850 ms
#
# 💾 Saving samples for n_mc=1200000...
# Computing empirical joint PMFs for lightweight save...
# Samples saved (LIGHTWEIGHT - Joint PMFs) to: gillespie_nmc_1200000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - File size: 189.85 MB
#   - n_mc: 1200000, N: 10
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Summary saved to: gillespie_nmc_1200000_summary/gillespie_nmc_1200000_summary_summary.json
#
# ======================================================================
# Running experiment with n_mc = 2000000
# ======================================================================
# Running forward process...
# Running Gillespie reverse process...
#   Gillespie particle 0/2000000
#   Gillespie particle 10000/2000000
#   Gillespie particle 20000/2000000
#   Gillespie particle 30000/2000000
#   Gillespie particle 40000/2000000
#   Gillespie particle 50000/2000000
#   Gillespie particle 60000/2000000
#   Gillespie particle 70000/2000000
#   Gillespie particle 80000/2000000
#   Gillespie particle 90000/2000000
#   Gillespie particle 100000/2000000
#   Gillespie particle 110000/2000000
#   Gillespie particle 120000/2000000
#   Gillespie particle 130000/2000000
#   Gillespie particle 140000/2000000
#   Gillespie particle 150000/2000000
#   Gillespie particle 160000/2000000
#   Gillespie particle 170000/2000000
#   Gillespie particle 180000/2000000
#   Gillespie particle 190000/2000000
#   Gillespie particle 200000/2000000
#   Gillespie particle 210000/2000000
#   Gillespie particle 220000/2000000
#   Gillespie particle 230000/2000000
#   Gillespie particle 240000/2000000
#   Gillespie particle 250000/2000000
#   Gillespie particle 260000/2000000
#   Gillespie particle 270000/2000000
#   Gillespie particle 280000/2000000
#   Gillespie particle 290000/2000000
#   Gillespie particle 300000/2000000
#   Gillespie particle 310000/2000000
#   Gillespie particle 320000/2000000
#   Gillespie particle 330000/2000000
#   Gillespie particle 340000/2000000
#   Gillespie particle 350000/2000000
#   Gillespie particle 360000/2000000
#   Gillespie particle 370000/2000000
#   Gillespie particle 380000/2000000
#   Gillespie particle 390000/2000000
#   Gillespie particle 400000/2000000
#   Gillespie particle 410000/2000000
#   Gillespie particle 420000/2000000
#   Gillespie particle 430000/2000000
#   Gillespie particle 440000/2000000
#   Gillespie particle 450000/2000000
#   Gillespie particle 460000/2000000
#   Gillespie particle 470000/2000000
#   Gillespie particle 480000/2000000
#   Gillespie particle 490000/2000000
#   Gillespie particle 500000/2000000
#   Gillespie particle 510000/2000000
#   Gillespie particle 520000/2000000
#   Gillespie particle 530000/2000000
#   Gillespie particle 540000/2000000
#   Gillespie particle 550000/2000000
#   Gillespie particle 560000/2000000
#   Gillespie particle 570000/2000000
#   Gillespie particle 580000/2000000
#   Gillespie particle 590000/2000000
#   Gillespie particle 600000/2000000
#   Gillespie particle 610000/2000000
#   Gillespie particle 620000/2000000
#   Gillespie particle 630000/2000000
#   Gillespie particle 640000/2000000
#   Gillespie particle 650000/2000000
#   Gillespie particle 660000/2000000
#   Gillespie particle 670000/2000000
#   Gillespie particle 680000/2000000
#   Gillespie particle 690000/2000000
#   Gillespie particle 700000/2000000
#   Gillespie particle 710000/2000000
#   Gillespie particle 720000/2000000
#   Gillespie particle 730000/2000000
#   Gillespie particle 740000/2000000
#   Gillespie particle 750000/2000000
#   Gillespie particle 760000/2000000
#   Gillespie particle 770000/2000000
#   Gillespie particle 780000/2000000
#   Gillespie particle 790000/2000000
#   Gillespie particle 800000/2000000
#   Gillespie particle 810000/2000000
#   Gillespie particle 820000/2000000
#   Gillespie particle 830000/2000000
#   Gillespie particle 840000/2000000
#   Gillespie particle 850000/2000000
#   Gillespie particle 860000/2000000
#   Gillespie particle 870000/2000000
#   Gillespie particle 880000/2000000
#   Gillespie particle 890000/2000000
#   Gillespie particle 900000/2000000
#   Gillespie particle 910000/2000000
#   Gillespie particle 920000/2000000
#   Gillespie particle 930000/2000000
#   Gillespie particle 940000/2000000
#   Gillespie particle 950000/2000000
#   Gillespie particle 960000/2000000
#   Gillespie particle 970000/2000000
#   Gillespie particle 980000/2000000
#   Gillespie particle 990000/2000000
#   Gillespie particle 1000000/2000000
#   Gillespie particle 1010000/2000000
#   Gillespie particle 1020000/2000000
#   Gillespie particle 1030000/2000000
#   Gillespie particle 1040000/2000000
#   Gillespie particle 1050000/2000000
#   Gillespie particle 1060000/2000000
#   Gillespie particle 1070000/2000000
#   Gillespie particle 1080000/2000000
#   Gillespie particle 1090000/2000000
#   Gillespie particle 1100000/2000000
#   Gillespie particle 1110000/2000000
#   Gillespie particle 1120000/2000000
#   Gillespie particle 1130000/2000000
#   Gillespie particle 1140000/2000000
#   Gillespie particle 1150000/2000000
#   Gillespie particle 1160000/2000000
#   Gillespie particle 1170000/2000000
#   Gillespie particle 1180000/2000000
#   Gillespie particle 1190000/2000000
#   Gillespie particle 1200000/2000000
#   Gillespie particle 1210000/2000000
#   Gillespie particle 1220000/2000000
#   Gillespie particle 1230000/2000000
#   Gillespie particle 1240000/2000000
#   Gillespie particle 1250000/2000000
#   Gillespie particle 1260000/2000000
#   Gillespie particle 1270000/2000000
#   Gillespie particle 1280000/2000000
#   Gillespie particle 1290000/2000000
#   Gillespie particle 1300000/2000000
#   Gillespie particle 1310000/2000000
#   Gillespie particle 1320000/2000000
#   Gillespie particle 1330000/2000000
#   Gillespie particle 1340000/2000000
#   Gillespie particle 1350000/2000000
#   Gillespie particle 1360000/2000000
#   Gillespie particle 1370000/2000000
#   Gillespie particle 1380000/2000000
#   Gillespie particle 1390000/2000000
#   Gillespie particle 1400000/2000000
#   Gillespie particle 1410000/2000000
#   Gillespie particle 1420000/2000000
#   Gillespie particle 1430000/2000000
#   Gillespie particle 1440000/2000000
#   Gillespie particle 1450000/2000000
#   Gillespie particle 1460000/2000000
#   Gillespie particle 1470000/2000000
#   Gillespie particle 1480000/2000000
#   Gillespie particle 1490000/2000000
#   Gillespie particle 1500000/2000000
#   Gillespie particle 1510000/2000000
#   Gillespie particle 1520000/2000000
#   Gillespie particle 1530000/2000000
#   Gillespie particle 1540000/2000000
#   Gillespie particle 1550000/2000000
#   Gillespie particle 1560000/2000000
#   Gillespie particle 1570000/2000000
#   Gillespie particle 1580000/2000000
#   Gillespie particle 1590000/2000000
#   Gillespie particle 1600000/2000000
#   Gillespie particle 1610000/2000000
#   Gillespie particle 1620000/2000000
#   Gillespie particle 1630000/2000000
#   Gillespie particle 1640000/2000000
#   Gillespie particle 1650000/2000000
#   Gillespie particle 1660000/2000000
#   Gillespie particle 1670000/2000000
#   Gillespie particle 1680000/2000000
#   Gillespie particle 1690000/2000000
#   Gillespie particle 1700000/2000000
#   Gillespie particle 1710000/2000000
#   Gillespie particle 1720000/2000000
#   Gillespie particle 1730000/2000000
#   Gillespie particle 1740000/2000000
#   Gillespie particle 1750000/2000000
#   Gillespie particle 1760000/2000000
#   Gillespie particle 1770000/2000000
#   Gillespie particle 1780000/2000000
#   Gillespie particle 1790000/2000000
#   Gillespie particle 1800000/2000000
#   Gillespie particle 1810000/2000000
#   Gillespie particle 1820000/2000000
#   Gillespie particle 1830000/2000000
#   Gillespie particle 1840000/2000000
#   Gillespie particle 1850000/2000000
#   Gillespie particle 1860000/2000000
#   Gillespie particle 1870000/2000000
#   Gillespie particle 1880000/2000000
#   Gillespie particle 1890000/2000000
#   Gillespie particle 1900000/2000000
#   Gillespie particle 1910000/2000000
#   Gillespie particle 1920000/2000000
#   Gillespie particle 1930000/2000000
#   Gillespie particle 1940000/2000000
#   Gillespie particle 1950000/2000000
#   Gillespie particle 1960000/2000000
#   Gillespie particle 1970000/2000000
#   Gillespie particle 1980000/2000000
#   Gillespie particle 1990000/2000000
#
# ⏱️  Timing for n_mc=2000000:
#   Forward sampling:   714.64 seconds (11.91 minutes)
#   Gillespie reverse:  1017.33 seconds (16.96 minutes)
#   Total:              1731.97 seconds (28.87 minutes)
#   Time per sample:    0.866 ms
#
# 💾 Saving samples for n_mc=2000000...
# Computing empirical joint PMFs for lightweight save...
# Samples saved (LIGHTWEIGHT - Joint PMFs) to: gillespie_nmc_2000000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - File size: 229.05 MB
#   - n_mc: 2000000, N: 10
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Summary saved to: gillespie_nmc_2000000_summary/gillespie_nmc_2000000_summary_summary.json
#
# ======================================================================
# VERIFICATION: Reloading saved samples and checking integrity
# ======================================================================
#
# Verifying n_mc=300000...
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_300000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 300000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 143
#     141     # Each dimension should sum to 1
#     142     for d in range(N):
# --> 143         pmf_sum = np.sum(forward_pmf[d, :])
#     144         assert np.abs(pmf_sum - 1.0) < 1e-6, \
#     145             f"Forward PMF doesn't sum to 1 at t={t}, dim={d} for n_mc={n_mc}"
#     147 # Verify reverse PMFs
#
# KeyError: (0, slice(None, None, None))

# %%
# ===== Check Masking Rate at t=T =====
print("\n" + "=" * 70)
print("MASKING RATE ANALYSIS AT t=T")
print("=" * 70)

for n_mc in n_mc_list:
    filename = filenames[n_mc]
    data, _ = load_samples(filename + '.pkl')
    
    # Get PMF at t=T (last checkpoint)
    t_final = data['times'][-1]
    forward_pmf_T = data['forward_pmfs'][float(t_final)]
    
    # PMF shape: (N, L+1) where last column (index L) is MASK
    mask_probs_per_dim = forward_pmf_T[:, L]  # Probability of MASK for each dimension
    
    # Average masking rate across all dimensions
    avg_mask_rate = np.mean(mask_probs_per_dim)
    
    # Theoretical masking rate at time T
    theoretical_mask_rate = 1 - np.exp(-beta * T)
    
    print(f"\nn_mc = {n_mc:7d}:")
    print(f"  Time T = {t_final:.6f}")
    print(f"  Empirical mask rate:   {avg_mask_rate:.6f}")
    print(f"  Theoretical mask rate: {theoretical_mask_rate:.6f}")
    print(f"  Difference:            {abs(avg_mask_rate - theoretical_mask_rate):.6f}")
    print(f"  Per-dimension mask rates: min={np.min(mask_probs_per_dim):.6f}, "
          f"max={np.max(mask_probs_per_dim):.6f}")
    
    # Check if close to theoretical
    if abs(avg_mask_rate - theoretical_mask_rate) < 0.01:
        print(f"  ✓ Masking rate matches theory!")
    else:
        print(f"  ⚠ Warning: Masking rate deviates from theory")
# Out:
# ======================================================================
# MASKING RATE ANALYSIS AT t=T
# ======================================================================
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_300000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 300000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#
# n_mc =  300000:
#   Time T = 3.500000
#   Empirical mask rate:   1.000000
#   Theoretical mask rate: 1.000000
#   Difference:            0.000000
#   Per-dimension mask rates: min=1.000000, max=1.000000
#   ✓ Masking rate matches theory!
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_600000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 600000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#
# n_mc =  600000:
#   Time T = 3.500000
#   Empirical mask rate:   1.000000
#   Theoretical mask rate: 1.000000
#   Difference:            0.000000
#   Per-dimension mask rates: min=1.000000, max=1.000000
#   ✓ Masking rate matches theory!
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_1200000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 1200000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#
# n_mc = 1200000:
#   Time T = 3.500000
#   Empirical mask rate:   1.000000
#   Theoretical mask rate: 1.000000
#   Difference:            0.000000
#   Per-dimension mask rates: min=1.000000, max=1.000000
#   ✓ Masking rate matches theory!
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_2000000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 2000000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#
# n_mc = 2000000:
#   Time T = 3.500000
#   Empirical mask rate:   1.000000
#   Theoretical mask rate: 1.000000
#   Difference:            0.000000
#   Per-dimension mask rates: min=1.000000, max=1.000000
#   ✓ Masking rate matches theory!

# %% [markdown]
# # change for verification

# %%
# ===== Reload and Verify =====
print("\n" + "=" * 70)
print("VERIFICATION: Reloading saved samples and checking integrity")
print("=" * 70)

for n_mc in n_mc_list:
    print(f"\nVerifying n_mc={n_mc}...")
    
    # Load samples (will be PMF dict, not DiffusionSamples object)
    filename = filenames[n_mc]
    loaded_data, loaded_metadata = load_samples(filename + '.pkl')
    
    # Original samples
    original_samples = samples_dict[n_mc]
    
    # Verify it's lightweight format
    assert loaded_data.get('lightweight', False) == True, \
        f"Expected lightweight format for {n_mc}"
    
    # Verify metadata
    assert loaded_data['metadata']['n_mc'] == original_samples.metadata['n_mc'], \
        f"n_mc mismatch for {n_mc}"
    assert loaded_data['metadata']['N'] == original_samples.metadata['N'], \
        f"N mismatch for {n_mc}"
    assert loaded_data['L'] == L, \
        f"L mismatch for {n_mc}"
    
    # Verify times
    assert np.allclose(loaded_data['times'], original_samples.times), \
        f"Times mismatch for {n_mc}"
    
    # Verify joint PMFs sum to 1
    for t in loaded_data['times']:
        forward_pmf = loaded_data['forward_pmfs'][float(t)]
        
        # Check that probabilities sum to 1
        prob_sum = np.sum(forward_pmf['probs'])
        assert np.abs(prob_sum - 1.0) < 1e-6, \
            f"Forward PMF probabilities don't sum to 1 at t={t} for n_mc={n_mc}: sum={prob_sum}"
        
        # Check that all probabilities are non-negative
        assert np.all(forward_pmf['probs'] >= 0), \
            f"Forward PMF has negative probabilities at t={t} for n_mc={n_mc}"
        
        # Check that states and probs have same length
        assert len(forward_pmf['states']) == len(forward_pmf['probs']), \
            f"States and probs length mismatch at t={t} for n_mc={n_mc}"
    
    # Verify reverse PMFs
    for method in loaded_data['reverse_pmfs'].keys():
        for t in loaded_data['times']:
            reverse_pmf = loaded_data['reverse_pmfs'][method][float(t)]
            
            # Check that probabilities sum to 1
            prob_sum = np.sum(reverse_pmf['probs'])
            assert np.abs(prob_sum - 1.0) < 1e-6, \
                f"Reverse PMF probabilities don't sum to 1 for method={method}, t={t}, n_mc={n_mc}: sum={prob_sum}"
            
            # Check that all probabilities are non-negative
            assert np.all(reverse_pmf['probs'] >= 0), \
                f"Reverse PMF has negative probabilities for method={method}, t={t}, n_mc={n_mc}"
            
            # Check that states and probs have same length
            assert len(reverse_pmf['states']) == len(reverse_pmf['probs']), \
                f"States and probs length mismatch for method={method}, t={t}, n_mc={n_mc}"
    
    print(f"  ✓ All checks passed for n_mc={n_mc}")
    print(f"  ✓ Joint PMFs verified (probabilities sum to 1)")

print("\n" + "=" * 70)
print("✓ ALL VERIFICATION CHECKS PASSED!")
print("=" * 70)
# Out:
# ======================================================================
# VERIFICATION: Reloading saved samples and checking integrity
# ======================================================================
#
# Verifying n_mc=300000...
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_300000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 300000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#   ✓ All checks passed for n_mc=300000
#   ✓ Joint PMFs verified (probabilities sum to 1)
#
# Verifying n_mc=600000...
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_600000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 600000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#   ✓ All checks passed for n_mc=600000
#   ✓ Joint PMFs verified (probabilities sum to 1)
#
# Verifying n_mc=1200000...
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_1200000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 1200000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#   ✓ All checks passed for n_mc=1200000
#   ✓ Joint PMFs verified (probabilities sum to 1)
#
# Verifying n_mc=2000000...
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_2000000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 2000000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
#   ✓ All checks passed for n_mc=2000000
#   ✓ Joint PMFs verified (probabilities sum to 1)
#
# ======================================================================
# ✓ ALL VERIFICATION CHECKS PASSED!
# ======================================================================

# %%
# ===== Plot Results =====
print("\n" + "=" * 70)
print("PLOTTING RESULTS")
print("=" * 70)

# Reload as PMF dicts for plotting
samples_dict_pmf = {}
for n_mc in n_mc_list:
    filename = filenames[n_mc]
    data, _ = load_samples(filename + '.pkl')
    samples_dict_pmf[n_mc] = data

# Plot comparison (plotting function handles PMF format)
fig, ax, results = plot_gillespie_nmc_comparison(
    samples_dict_pmf,
    time_start=0.0,
    time_end=T,
    filename='gillespie_nmc_comparison.png',
    show_annotations=True
)

# Print final Hellinger distances
print("\n" + "=" * 70)
print("FINAL HELLINGER DISTANCES")
print("=" * 70)
for n_mc, hellinger in sorted(results.items()):
    print(f"  n_mc={n_mc:7d}: H={hellinger:.6f}")

# Print timing summary
print("\n" + "=" * 70)
print("TIMING SUMMARY")
print("=" * 70)
print(f"{'n_mc':<12} {'Forward':<12} {'Gillespie':<12} {'Total':<12} {'Per Sample'}")
print(f"{'':12} {'(min)':<12} {'(min)':<12} {'(min)':<12} {'(ms)'}")
print("-" * 70)
for n_mc in sorted(timing_results.keys()):
    t = timing_results[n_mc]
    print(f"{n_mc:<12,} {t['forward']/60:>10.2f}  {t['gillespie']/60:>10.2f}  "
          f"{t['total']/60:>10.2f}  {(t['total']/n_mc)*1000:>10.3f}")

# Print file sizes
print("\n" + "=" * 70)
print("FILE SIZES (LIGHTWEIGHT PMF SAVES)")
print("=" * 70)
for n_mc in n_mc_list:
    filename = filenames[n_mc]
    filepath = f"{filename}/{filename}.pkl"
    if os.path.exists(filepath):
        size_mb = os.path.getsize(filepath) / (1024 * 1024)
        print(f"  n_mc={n_mc:7d}: {size_mb:.2f} MB")

# Plot zoomed version near t=0
print("\nCreating zoomed plot near t=0...")
fig_zoom, ax_zoom, _ = plot_gillespie_nmc_comparison(
    samples_dict_pmf,
    time_start=0.0,
    time_end=0.5,
    filename='gillespie_nmc_comparison_zoom.png',
    show_annotations=False
)

print("\n" + "=" * 70)
print("EXPERIMENT COMPLETE!")
print("=" * 70)
print(f"\nGenerated files:")
for n_mc in n_mc_list:
    print(f"  - {filenames[n_mc]}/")
    print(f"    ├── {filenames[n_mc]}.pkl (LIGHTWEIGHT PMF)")
    print(f"    └── {filenames[n_mc]}_summary.json")
print(f"  - gillespie_nmc_comparison.png")
print(f"  - gillespie_nmc_comparison_zoom.png")
# Out:
# ======================================================================
# PLOTTING RESULTS
# ======================================================================
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_300000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 300000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_600000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 600000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_1200000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 1200000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Samples loaded (LIGHTWEIGHT - PMFs) from: gillespie_nmc_2000000.pkl
#   - Forward PMFs: 31 checkpoints
#   - Reverse PMFs: 1 methods
#   - n_mc: 2000000, N: 10, L: 3
#   - User metadata: ['N', 'L', 'r', 'beta', 'T', 'n_mc', 'w', 'mu', 'checkpoint_formula', 'n_checkpoints', 'methods', 'timing', 'date', 'notes']
# Plot saved to: gillespie_nmc_comparison.png
# ======================================================================
# FINAL HELLINGER DISTANCES
# ======================================================================
#   n_mc= 300000: H=0.000000
#   n_mc= 600000: H=0.000000
#   n_mc=1200000: H=0.000000
#   n_mc=2000000: H=0.000500
#
# ======================================================================
# TIMING SUMMARY
# ======================================================================
# n_mc         Forward      Gillespie    Total        Per Sample
#              (min)        (min)        (min)        (ms)
# ----------------------------------------------------------------------
# 300,000            1.75        2.47        4.23       0.845
# 600,000            3.48        4.99        8.47       0.847
# 1,200,000          7.04        9.96       17.01       0.850
# 2,000,000         11.91       16.96       28.87       0.866
#
# ======================================================================
# FILE SIZES (LIGHTWEIGHT PMF SAVES)
# ======================================================================
#   n_mc= 300000: 101.31 MB
#   n_mc= 600000: 141.53 MB
#   n_mc=1200000: 189.85 MB
#   n_mc=2000000: 229.05 MB
#
# Creating zoomed plot near t=0...
# Plot saved to: gillespie_nmc_comparison_zoom.png
# ======================================================================
# EXPERIMENT COMPLETE!
# ======================================================================
#
# Generated files:
#   - gillespie_nmc_300000/
#     ├── gillespie_nmc_300000.pkl (LIGHTWEIGHT PMF)
#     └── gillespie_nmc_300000_summary.json
#   - gillespie_nmc_600000/
#     ├── gillespie_nmc_600000.pkl (LIGHTWEIGHT PMF)
#     └── gillespie_nmc_600000_summary.json
#   - gillespie_nmc_1200000/
#     ├── gillespie_nmc_1200000.pkl (LIGHTWEIGHT PMF)
#     └── gillespie_nmc_1200000_summary.json
#   - gillespie_nmc_2000000/
#     ├── gillespie_nmc_2000000.pkl (LIGHTWEIGHT PMF)
#     └── gillespie_nmc_2000000_summary.json
#   - gillespie_nmc_comparison.png
#   - gillespie_nmc_comparison_zoom.png
